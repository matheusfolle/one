# %% [markdown]
# Bruno gerencia um pequeno comércio e quer saber qual produto teve o melhor desempenho de vendas no mês passado. Ele registrou a quantidade vendida de dois produtos: maçãs e bananas. Agora, ele precisa escrever um programa que identifique e exiba qual deles teve maior venda.
#
# Crie um programa que receba o número de vendas dos dois produtos e exiba uma mensagem indicando qual deles vendeu mais. Se as quantidades forem iguais, exiba uma mensagem dizendo que houve empate.

# %%
macas = int(input("Informe a quantidade de maçãs vendidas: "))
bananas = int(input("Informe a quantidade de bananas vendidas: "))

if macas > bananas:
  print("Foram vendidas %i maçãs" %(macas))
elif bananas > macas:
  print("Foram vendidas %i bananas" %(bananas))
else:
  print("Houve um empate nas vendas.")
# Out:
# Informe a quantidade de maçãs vendidas: 10
# Informe a quantidade de bananas vendidas: 10
# Houve um empate nas vendas.

# %% [markdown]
# Camila está organizando um projeto e precisa calcular o tempo total necessário para concluir três atividades: A, B e C. No entanto, se alguma atividade tiver um número de dias negativo, o código deve avisar que os valores inseridos são inválidos e não calcular o total.
#
# Escreva um programa que receba o número de dias de três atividades e exiba o tempo total do projeto. Se algum valor for negativo, mostre uma mensagem informando o erro.

# %%
dias = []

for i in range(1, 4):
  dia = int(input(f"Informe os dias da atividade {i}: "))
  if dia <= 0:
    print("Erro! Os dias não podem ser negativos.")
    break
  else:
    dias.append(dia)

if len(dias) == 3:
  print(f"O total do projeto é {sum(dias)}. Bom projeto a todos os envolvidos!")
# Out:
# Informe os dias da atividade 1: 3
# Informe os dias da atividade 2: 6
# Informe os dias da atividade 3: -8
# Erro! Os dias não podem ser negativos.

# %%
dias = []
opcao = "1"
while opcao == "1":
  dias.clear()
  for i in range(3):
    dia = int(input(f"Informe o número de dias da {i+1}º atividade: "))
    if dia > 0:
      dias.append(dia)
    else:
      print("Erro! os dias devem ser positivos.")
      break

  if len(dias) == 3:
    print(f"Tempo total do projeto: {sum(dias)} dias.")
  else:
    print(f"Erro no cadastro de dias!")

  print("Deseja calcular outro projeto?")
  opcao = input("1 - Sim | 2 - Não: ").strip()
print("Obrigado por utilizar a calculadora de projetos!")

# %% [markdown]
# Lucas trabalha em TI e precisa garantir que a temperatura de uma sala de servidores não ultrapasse 25°C. Ele quer um programa que receba a temperatura atual como entrada e, se necessário, exiba uma mensagem de alerta.

# %%
temperatura = int(input("Digite a temperatura atual: "))

if temperatura >= 25:
  print("Alerta! Temperatura acima do limite permitido.")
else:
  print("Temperatura adicionada.")
# Out:
# Digite a temperatura atual: 40
# Alerta! Temperatura acima do limite permitido.

# %% [markdown]
# Anna Júlia está criando um sistema para calcular o Índice de Massa Corporal (IMC) e fornecer recomendações básicas.
#
# O programa deve receber o peso e a altura de uma pessoa e exibir o valor do IMC, além de indicar se está abaixo do peso, com peso normal ou acima do peso.
#
# Crie um programa que receba o peso (em kg) e a altura (em metros) e calcule o IMC usando a fórmula: IMC = peso / (altura ** 2)
#
# Depois, exiba o valor do IMC e uma mensagem indicando se está abaixo do peso (IMC < 18.5), peso normal (18.5 <= IMC < 25) ou acima do peso (IMC >= 25).

# %%
program = True
while program:
  peso = float(input("Bem-vindo ao cálculo de IMC.\nPara continuar, digite seu peso (em kg):\nPara sair, pressione 0 \n"))
  if peso == 0:
    program = False
    print("Saindo...")
  elif peso < 0:
    print("Informe um valor de peso (em kg) verdadeiro para o cálculo!")
  else:
    altura = float(input("Agora informe sua altura (em metros): "))
    quadrado_da_altura = pow(altura, 2)
    IMC = peso / quadrado_da_altura
    if IMC > 0:
      if 18.5 > IMC:
        print(f"IMC: {IMC:.2f}. Você está abaixo do peso.")
      elif IMC < 25:
        print(f"IMC: {IMC:.2f}. Você tem peso normal.")
      else:
        print(f"IMC: {IMC:.2f}. Você está acima do peso.")
      print("Obrigado por usar o cálculo de IMC!")

# %% [markdown]
# Carlos quer monitorar seu orçamento mensal para evitar gastos excessivos. Ele estabeleceu um limite de R$ 3.000,00 para seus gastos e precisa de um programa que ajude a controlar suas despesas.
#
# O programa deve receber o total de despesas realizadas e informar se ele ultrapassou o limite ou ainda está dentro do orçamento.

# %%
limite = 3000

despesas = float(input("Informe suas despesas mensais: "))
while despesas <= 0:
  despesas = float(input("Informe suas despesas mensais (o valor deve ser positivo): "))

if despesas > limite:
  print("Você ultrapassou o seu limite de despesas!")
else:
  print("Dentro do orçamento.")

# %%
program = True

while program:
  despesas = float(input("Digite o total de despesas do mês:\n(Para sair digite 0): \n"))
  while despesas < 0:
      despesas = float(input("Digite o total de despesas do mês, o valor de despesas deve ser positivo: "))
  if despesas == 0:
    print("Saindo...")
    program = False
  elif despesas <= 3.000:
    print("Você está dentro do limite orçamentário!")
  else:
    print("Cuidado! Você ultrapassou o limite do orçamento.")

# %%
limite = 3000.0
despesas = float(input("Digite o total de despesas do mês (R$): "))

if despesas > limite:
    print("Atenção! Você ultrapassou o limite do orçamento.")
else:
    print("Você está dentro do orçamento.")

# %% [markdown]
# Mariana é responsável por liberar o acesso ao escritório e precisa de um programa que verifique se os funcionários podem entrar. Para isso, ela usará o horário atual. O escritório só permite acesso entre 8h e 18h.
#
# Crie um programa que receba a hora atual como entrada (em formato de 24 horas) e exiba uma mensagem informando se o acesso é permitido ou negado.

# %%
horario_atual = int(input("Informe o horário atual (24h): "))

if 8 <= horario_atual < 18:
  print("Entrada permitida!")
else:
  print("Entrada negada!")

# %%
horario_atual = int(input("Digite o horário atual (24h): "))

if 8 <= horario_atual < 18:
  print("Bem-vindo!")
else:
  print("Acesso negado!")
# Out:
# Digite o horário atual (24h): 6
# Acesso negado!

# %% [markdown]
# Uma professora precisa de um programa que ajude a calcular a média final dos alunos e informe se foram aprovados, ficaram de recuperação ou reprovados.
#
# As regras são:
# - Média >= 7: Aprovado
# - 5 <= Média < 7: Recuperação
# - Média < 5: Reprovado
#
# Escreva um programa que receba três notas como entrada e calcule a média final. Com base na média, exiba a situação do aluno.

# %%
notas = []
for i in range(1, 4):
  notas.append(float(input(f"Informe a {i}º nota: ")))
media = sum(notas) / len(notas)

if media >= 7:
  print("Aprovado!")
elif 5 <= media < 7:
  print("Recuperação.")
elif media < 5:
  print("Reprovado.")
# Out:
# Informe a 1º nota: 0
# Informe a 2º nota: 0
# Informe a 3º nota: 0
# Reprovado.

# %%
# List comprehension (mais conciso)
notas = [float(input(f"Informe a {i}º nota: ")) for i in range(1, 4)]
media = sum(notas) / len(notas)

# %%
program = 1
notas = []

while program == 1:
  print("Bem-vindo ao calculo de médias!")
  notas.clear()

  for i in range(3):
    nota = float(input(f"Informe a {i+1}º nota: "))

    while nota < 0 or nota > 10:
      nota = float(input(f"Informe a {i+1}º nota (0 a 10): "))

    notas.append(nota)

  media_notas = sum(notas)/len(notas)

  if media_notas >= 7:
    print("Aprovado!\n")
  elif media_notas >= 5:
    print("Recuperação!\n")
  else:
    print("Reprovado!\n")

  print(f"Média final: {media_notas:.2f}\n")
  print("Deseja calcular outra média?")
  program = int(input("1 - Sim | 2 - Não: "))
print("Obrigado por utilizar o calculo de médias.")

# %% [markdown]
# Fernanda está planejando uma viagem e quer calcular quanto pagará de pedágio. O valor do pedágio depende da distância percorrida:
#
# - Até 100 km: R$ 10,00
#
# - Entre 100km e 200km: R$ 20,00
#
# - Acima de 200 km: R$ 30,00
#
# Crie um programa que receba a distância percorrida e informe o valor do pedágio correspondente.

# %%
distancia = float(input("Informe a distância percorrida (em kilômetros): "))

if distancia <= 100:
  print("Pedágio de R$ 10,00")
elif 100 < distancia <= 200:
  print("Pedágio de R$ 20,00")
else:
  print("Pedágio de R$ 30,00")
# Out:
# Informe a distância percorrida: 200
# Pedágio de R$ 20,00

# %%
kilometragem = int(input("Informe a kilometragem para descobrir o valor do pedágio: "))

while kilometragem <= 0:
  kilometragem = int(input("Informe a kilometragem (em valores reais): "))

if kilometragem < 100:
  print("R$ 10,00")
elif kilometragem <= 200:
  print("R$ 20,00")
else:
  print("R$ 30,00")

# %% [markdown]
# Lucas está desenvolvendo um jogo e precisa de uma funcionalidade que verifique se um número é par ou ímpar. Essa verificação será usada para definir ações diferentes dentro do jogo.
#
# Escreva um programa que receba um número inteiro e exiba uma mensagem informando se ele é par ou ímpar.

# %%
numero = int(input("Digite um número inteiro: "))

while numero <= 0:
  numero = int(input("Digite um número inteiro positivo: "))

if numero % 2 == 0:
  print("Número par.")
else:
  print("Número ímpar.")
# Out:
# Digite um número inteiro: -22
# Digite um número inteiro: -33
# Digite um número inteiro: 9
# Número ímpar.

# %% [markdown]
# Pedro quer solicitar um empréstimo, mas a aprovação depende de duas condições:
#
# - O valor da renda mensal precisa ser maior que R$ 2.000,00.
# - O valor da parcela não pode ultrapassar 30% da renda.
#
# Crie um programa que receba como entrada a renda mensal de Pedro e o valor da parcela desejada. O programa deve informar se o empréstimo foi aprovado ou negado com base nas condições acima.

# %%
min_renda = 2000

renda = float(input("Informe a sua renda atual: "))
while renda < min_renda:
  renda = float(input("Informe a sua renda atual (mínimo 2000): "))

parcela = float(input("Informe o valor da parcela desejada: "))
max_parcela = renda * 0.30

if parcela > max_parcela:
  print("Empréstimo não aprovado.")
else:
  print("Empréstimo aprovado!")
# Out:
# Informe a sua renda atual: 2500
# Informe o valor da parcela desejada: 900
# Empréstimo não aprovado.

# %%
renda = float(input("Digite o valor da renda mensal (min 2.000): "))

while renda < 2000:
  renda = float(input("Digite o valor da renda mensal (min 2.000): "))

comprometimento = float(input("Digite o valor máximo de parcela desejada: "))

parcela_maxima = renda * 0.30

if comprometimento > parcela_maxima:
  print("Empréstimo reprovado. Parcela acima de 30% da renda.")
else:
  print("Empréstimo aprovado!")
# Out:
# Digite o valor da renda mensal (min 2.000): 2100
# Digite o valor máximo de parcela desejada: 700
# 2100.0
# 700.0
# Empréstimo reprovado. Parcela acima de 30% da renda.

# %%
renda = float(input("Digite o valor da sua renda mensal: "))
parcela = float(input("Digite o valor da parcela desejada: "))

if renda > 2000 and parcela <= 0.3 * renda:
    print("Empréstimo aprovado!")
elif renda <= 2000:
    print("Empréstimo negado: renda insuficiente.")
else:
    print("Empréstimo negado: parcela acima de 30% da renda.")
