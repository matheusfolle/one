# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
fat_1 = loja['Preço'].sum()

# %%
fat_2 = loja2['Preço'].sum()

# %%
fat_3 = loja3['Preço'].sum()

# %%
fat_4 = loja4['Preço'].sum()

# %%
print(f"Faturamento das lojas: \nLoja 1: {fat_1:.2f}\nLoja 2: {fat_2:.2f}\nLoja 3: {fat_3:.2f}\nLoja 4: {fat_4:.2f}")
# Out:
# Faturamento das lojas:
# Loja 1: 1534509.12
# Loja 2: 1488459.06
# Loja 3: 1464025.03
# Loja 4: 1384497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
vendas_por_cat_loja = loja.groupby('Categoria do Produto')['Preço'].count()

# %%
vendas_por_cat_loja2 = loja2.groupby('Categoria do Produto')['Preço'].count()

# %%
vendas_por_cat_loja3 = loja3.groupby('Categoria do Produto')['Preço'].count()

# %%
vendas_por_cat_loja4 = loja4.groupby('Categoria do Produto')['Preço'].count()

# %%
print(f"==========================================================================================\n                                VENDAS POR LOJA E CATEGORIA\n==========================================================================================\nLOJA 1: {vendas_por_cat_loja}==========================================================================================\n                                VENDAS POR LOJA E CATEGORIA\n==========================================================================================)\nLOJA 2: {vendas_por_cat_loja2}==========================================================================================\n                                VENDAS POR LOJA E CATEGORIA\n==========================================================================================\nLOJA 3: {vendas_por_cat_loja3}==========================================================================================\n                                VENDAS POR LOJA E CATEGORIA\n==========================================================================================\nLOJA 4:{vendas_por_cat_loja4}==========================================================================================\n                                VENDAS POR LOJA E CATEGORIA\n==========================================================================================")
# Out:
# ...
#                                 VENDAS POR LOJA E CATEGORIA
# ...
# LOJA 1: Categoria do Produto
# brinquedos               338
# eletrodomesticos         254
# eletronicos              451
# esporte e lazer          277
# instrumentos musicais    170
# livros                   187
# moveis                   480
# utilidades domesticas    201
# Name: Preço, dtype: int64==========================================================================================
#                                 VENDAS POR LOJA E CATEGORIA
# ==========================================================================================)
# LOJA 2: Categoria do Produto
# brinquedos               313
# eletrodomesticos         305
# eletronicos              422
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# moveis                   442
# utilidades domesticas    181
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
media_loja1 = loja['Avaliação da compra'].mean()

# %%
media_loja2 = loja2['Avaliação da compra'].mean()

# %%
media_loja3 = loja3['Avaliação da compra'].mean()

# %%
media_loja4 = loja4['Avaliação da compra'].mean()

# %%
print(f"Média Loja 1: {media_loja1:.2f}\nMédia Loja 2: {media_loja2:.2f}\nMédia Loja 3: {media_loja3:.2f}\nMédia Loja 4: {media_loja4:.2f}")
# Out:
# Média Loja 1: 3.98
# Média Loja 2: 4.04
# Média Loja 3: 4.05
# Média Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
produtos_mais_vendidos_loja = loja.groupby('Produto')['Produto'].count().sort_values(ascending=False)

# %%
produtos_menos_vendidos_loja = loja.groupby('Produto')['Produto'].count().sort_values(ascending=True)

# %%
produtos_mais_vendidos_loja2 = loja2.groupby('Produto')['Produto'].count().sort_values(ascending=False)

# %%
produtos_menos_vendidos_loja2 = loja2.groupby('Produto')['Produto'].count().sort_values(ascending=True)

# %%
produtos_mais_vendidos_loja3 = loja3.groupby('Produto')['Produto'].count().sort_values(ascending=False)

# %%
produtos_menos_vendidos_loja3 = loja3.groupby('Produto')['Produto'].count().sort_values(ascending=True)

# %%
produtos_mais_vendidos_loja4 = loja4.groupby('Produto')['Produto'].count().sort_values(ascending=False)

# %%
produtos_menos_vendidos_loja4 = loja4.groupby('Produto')['Produto'].count().sort_values(ascending=True)

# %%
import matplotlib.pyplot as plt

top5_mais = produtos_mais_vendidos_loja.head(5)

top5_mais.plot(kind='bar', figsize=(10, 6), color='lightblue')
plt.title('Top 5 Produtos Mais Vendidos - Loja 1')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_menos = produtos_menos_vendidos_loja.head(5)

top5_menos.plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('Top 5 Inverso de Produtos Menos Vendidos - Loja 1')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_mais2 = produtos_mais_vendidos_loja2.head(5)

top5_mais2.plot(kind='bar', figsize=(10, 6), color='lightblue')
plt.title('Top 5 Produtos Mais Vendidos - Loja 2')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_menos2 = produtos_menos_vendidos_loja2.head(5)

top5_menos2.plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('Top 5 Inverso de Produtos Menos Vendidos - Loja 2')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_mais3 = produtos_mais_vendidos_loja3.head(5)

top5_mais3.plot(kind='bar', figsize=(10, 6), color='lightblue')
plt.title('Top 5 Produtos Mais Vendidos - Loja 3')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_menos3 = produtos_menos_vendidos_loja.head(5)

top5_menos3.plot(kind='bar', figsize=(10, 6), color='blue')
plt.title('Top 5 Inverso de Produtos Menos Vendidos - Loja 3')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_mais4 = produtos_mais_vendidos_loja.head(5)

top5_mais4.plot(kind='bar', figsize=(10, 6), color='lightblue')
plt.title('Top 5 Produtos Mais Vendidos - Loja 4')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %%
top5_menos4 = produtos_menos_vendidos_loja4.head(5)

top5_menos4.plot(kind='bar', figsize=(10, 6), color='lightblue')
plt.title('Top 5 Inverso de Produtos Menos Vendidos - Loja 4')
plt.xlabel('Produto')
plt.ylabel('Quantidade Vendida')
plt.show()

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
media_frete_loja = loja['Frete'].mean()

# %%
media_frete_loja2 = loja2['Frete'].mean()

# %%
media_frete_loja3 = loja3['Frete'].mean()

# %%
media_frete_loja4 = loja4['Frete'].mean()

# %%
print(f"Média Frete Loja 1: R$ {media_frete_loja:.2f}\nMédia Frete Loja 2: R$ {media_frete_loja2:.2f}\nMédia Frete Loja 3: R$ {media_frete_loja3:.2f}\nMédia Frete Loja 4: R$ {media_frete_loja4:.2f}")
# Out:
# Média Frete Loja 1: R$ 34.69
# Média Frete Loja 2: R$ 33.62
# Média Frete Loja 3: R$ 33.07
# Média Frete Loja 4: R$ 31.28

# %% [markdown]
# # Gráficos Finais

# %%
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
medias_avaliacao = [media_loja1, media_loja2, media_loja3, media_loja4]

plt.figure(figsize=(10, 6))
plt.barh(lojas, medias_avaliacao, color='lightgreen')
plt.title('Média de Avaliação por Loja')
plt.xlabel('Avaliação Média')
plt.ylabel('Loja')
plt.tight_layout()
plt.show()

# %%
medias_frete = [media_frete_loja, media_frete_loja2, media_frete_loja3, media_frete_loja4]

plt.figure(figsize=(10, 6))
plt.plot(lojas, medias_frete, marker='o', color='red', linewidth=2)
plt.title('Custo Médio de Frete por Loja')
plt.xlabel('Loja')
plt.ylabel('Frete Médio (R$)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [fat_1, fat_2, fat_3, fat_4]

plt.figure(figsize=(10, 6))
plt.bar(lojas, faturamentos, color='lightgreen')
plt.title('Faturamento total por Loja')
plt.xlabel('Loja')
plt.ylabel('Faturamento em reais')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Relatório

# %% [markdown]
# Caro Sr. João, após analisar os dados das quatro lojas considerando faturamento, avaliação de clientes, custo de frete e desempenho de produtos, nossa recomendação é a venda da Loja 1. A análise revelou que, apesar dessa loja apresentar o maior faturamento entre todas, ela possui indicadores operacionais preocupantes que sugerem problemas estruturais.
#
# A Loja 1 tem a pior avaliação de clientes e o frete mais caro em comparação com as outras lojas. Isso pode indicar ineficiência logística ou problemas de atendimento que afetam a satisfação dos clientes. Enquanto isso, as Lojas 2, 3 e 4 apresentam desempenho mais equilibrado, com avaliações melhores e custos operacionais menores, o que sugere operações mais saudáveis.
#
# A última cartada está no valor de faturamento. Como a Loja 1 lidera em receita, ela pode atrair um comprador disposto a pagar um preço mais alto pela aquisição. Esse valor de venda pode ser reinvestido nas outras três lojas para aplicar estratégias de crescimento e fortalecer o negócio como um todo.
